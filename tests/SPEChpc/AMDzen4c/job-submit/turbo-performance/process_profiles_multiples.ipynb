# %% [markdown]
# # LIKWID policy-* summary
#
# Run this notebook from a policy folder such as `performance/` or `ondemand/`.
# It auto-detects subfolders like `<policy>-*` and computes:
# - Total runtime [s]
# - Average total power [W]
# - Total energy [J]
# - EDP [J*s]

# %%
from __future__ import annotations

from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# Settings
base_dir = Path('.')  # run from policy folder (e.g., performance/, ondemand/)
policy_name = base_dir.resolve().name
subfolder_pattern = f'{policy_name}-*'
benchmark_name = None  # None => process all detected benchmarks; set to a name to filter
skip_initial = 3
output_dir = base_dir  # per-benchmark CSV files are written here

# %%
import sys
from pathlib import Path

repo_root = None
for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents]:
    if (candidate / 'tests' / 'common' / 'process_profiles_lib.py').is_file():
        repo_root = candidate
        break

if repo_root is None:
    raise RuntimeError('Could not locate tests/common/process_profiles_lib.py from current notebook path')

lib_dir = repo_root / 'tests' / 'common'
if str(lib_dir) not in sys.path:
    sys.path.insert(0, str(lib_dir))

from process_profiles_lib import (
    SUM_FIELDS,
    build_policy_summary,
    extract_job_id,
    find_stdout_for_job,
    list_profiles,
    load_likwid_profile,
    newest_profile_for_benchmark,
    plot_benchmark_boxplots,
    plot_likwid_timeseries,
    print_policy_context,
    run_has_fatal_error,
    summarize_profile,
)

# %%
per_benchmark_summary, all_output = build_policy_summary(
    base_dir=base_dir,
    subfolder_pattern=subfolder_pattern,
    benchmark_name=benchmark_name,
    skip_initial=skip_initial,
    output_dir=output_dir,
    policy_name=policy_name,
)

print_policy_context(policy_name, subfolder_pattern, benchmark_name)
all_output
# Out:
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# Removed 15 extreme-high LIKWID samples using automatic power filtering
# Removed 10 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 29 extreme-high LIKWID samples using automatic power filtering
# Removed 13 extreme-high LIKWID samples using automatic power filtering
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# Removed 30 extreme-high LIKWID samples using automatic power filtering
# Removed 22 extreme-high LIKWID samples using automatic power filtering
# Removed 22 extreme-high LIKWID samples using automatic power filtering
# Removed 14 extreme-high LIKWID samples using automatic power filtering
# Removed 10 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 26 extreme-high LIKWID samples using automatic power filtering
# Removed 14 extreme-high LIKWID samples using automatic power filtering
# Removed 17 extreme-high LIKWID samples using automatic power filtering
# Removed 29 extreme-high LIKWID samples using automatic power filtering
# Removed 21 extreme-high LIKWID samples using automatic power filtering
# Removed 22 extreme-high LIKWID samples using automatic power filtering
# Removed 14 extreme-high LIKWID samples using automatic power filtering
# Removed 10 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 30 extreme-high LIKWID samples using automatic power filtering
# Removed 14 extreme-high LIKWID samples using automatic power filtering
# Removed 15 extreme-high LIKWID samples using automatic power filtering
# Removed 24 extreme-high LIKWID samples using automatic power filtering
# Removed 17 extreme-high LIKWID samples using automatic power filtering
# Removed 17 extreme-high LIKWID samples using automatic power filtering
# Removed 10 extreme-high LIKWID samples using automatic power filtering
# Removed 10 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 24 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 30 extreme-high LIKWID samples using automatic power filtering
# Removed 23 extreme-high LIKWID samples using automatic power filtering
# Removed 17 extreme-high LIKWID samples using automatic power filtering
# Removed 17 extreme-high LIKWID samples using automatic power filtering
# Removed 11 extreme-high LIKWID samples using automatic power filtering
# Removed 10 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 27 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 23 extreme-high LIKWID samples using automatic power filtering
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# [clvleaf] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_clvleaf.csv
# [hpgmgfv] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_hpgmgfv.csv
# [lbm] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_lbm.csv
# [miniswp] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_miniswp.csv
# [pot3d] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_pot3d.csv
# [soma] Detected abnormal runs with extreme-high values (excluded from plots/averages/csv): turbo-performance-2
# [soma] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_soma.csv
# [sph_exa] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_sph_exa.csv
# [tealeaf] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_tealeaf.csv
# [weather] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPEChpc/AMDzen4c/job-submit/turbo-performance/turbo-performance_summary_weather.csv
# Policy folder: turbo-performance
# Subfolder pattern: turbo-performance-*
# Benchmark filter: all detected benchmarks
#               subfolder benchmark  Total runtime [s]  Average total power [W]  \
# 0               Average   clvleaf            2452.73                   532.41
# 1   turbo-performance-0   clvleaf            2460.92                   480.54
# 2   turbo-performance-1   clvleaf            2445.38                   613.07
# 3   turbo-performance-2   clvleaf            2444.44                   620.66
# 4   turbo-performance-3   clvleaf            2456.53                   471.74
# 5   turbo-performance-4   clvleaf            2456.37                   476.07
# 6               Average   hpgmgfv            1286.16                   650.82
# 7   turbo-performance-0   hpgmgfv            1280.02                   715.10
# 8   turbo-performance-1   hpgmgfv            1288.04                   733.43
# 9   turbo-performance-2   hpgmgfv            1259.95                   726.82
# 10  turbo-performance-3   hpgmgfv            1303.65                   536.68
# 11  turbo-performance-4   hpgmgfv            1299.15                   542.06
# 12              Average       lbm             891.17                   756.19
# 13  turbo-performance-0       lbm             829.63                   812.66
# 14  turbo-performance-1       lbm             820.12                   818.41
# 15  turbo-performance-2       lbm             853.18                   819.04
# 16  turbo-performance-3       lbm             960.46                   664.31
# 17  turbo-performance-4       lbm             992.44                   666.50
# 18              Average   miniswp             583.33                   740.05
# 19  turbo-performance-0   miniswp             546.55                   807.48
# 20  turbo-performance-1   miniswp             546.06                   808.05
# 21  turbo-performance-2   miniswp             545.55                   807.79
# 22  turbo-performance-3   miniswp             638.24                   641.95
# 23  turbo-performance-4   miniswp             640.24                   634.96
# 24              Average     pot3d            2655.50                   557.68
# 25  turbo-performance-0     pot3d            2671.81                   613.82
# 26  turbo-performance-1     pot3d            2655.34                   608.49
# 27  turbo-performance-2     pot3d            2664.33                   612.29
# 28  turbo-performance-3     pot3d            2642.77                   480.18
# 29  turbo-performance-4     pot3d            2643.25                   473.63
# 30              Average      soma            1317.41                   642.14
# 31  turbo-performance-0      soma            1230.36                   732.04
# 32  turbo-performance-1      soma            1239.38                   728.13
# 33  turbo-performance-3      soma            1401.15                   556.36
# 34  turbo-performance-4      soma            1398.75                   552.04
# 35              Average   sph_exa            1529.19                   630.95
# 36  turbo-performance-0   sph_exa            1378.95                   759.73
# 37  turbo-performance-1   sph_exa            1415.63                   743.20
# 38  turbo-performance-2   sph_exa            1681.81                   540.59
# 39  turbo-performance-3   sph_exa            1619.62                   558.09
# 40  turbo-performance-4   sph_exa            1549.95                   553.12
# 41              Average   tealeaf            3228.15                   515.26
# 42  turbo-performance-0   tealeaf            3220.43                   606.12
# 43  turbo-performance-1   tealeaf            3222.91                   593.98
# 44  turbo-performance-2   tealeaf            3235.96                   461.16
# 45  turbo-performance-3   tealeaf            3229.62                   463.71
# 46  turbo-performance-4   tealeaf            3231.85                   451.32
# 47              Average   weather            1757.62                   721.60
# 48  turbo-performance-0   weather            1752.48                   826.07
# 49  turbo-performance-1   weather            1766.48                   819.88
# 50  turbo-performance-2   weather            1756.59                   657.25
# 51  turbo-performance-3   weather            1756.47                   652.80
# 52  turbo-performance-4   weather            1756.06                   651.98
#
#     Total energy [J]     EDP [J*s]
# 0         1304711.94  3.199057e+09
# 1         1181973.48  2.908748e+09
# 2         1498463.83  3.664312e+09
# 3         1516376.43  3.706693e+09
# 4         1158224.48  2.845209e+09
# 5         1168521.47  2.870323e+09
# 6          835165.11  1.072866e+09
# 7          914543.81  1.170636e+09
# 8          943863.80  1.215739e+09
# 9          914976.27  1.152826e+09
# 10         698995.22  9.112485e+08
# 11         703446.47  9.138814e+08
# 12         667912.60  5.943235e+08
# 13         673313.50  5.585982e+08
# 14         670290.51  5.497200e+08
# 15         697892.38  5.954292e+08
# 16         637326.85  6.121258e+08
# 17         660739.75  6.557441e+08
# 18         426918.45  2.483054e+08
# 19         440332.12  2.406648e+08
# 20         439684.76  2.400964e+08
# 21         439789.48  2.399288e+08
# 22         408979.20  2.610250e+08
# 23         405806.69  2.598120e+08
# 24        1480630.39  3.933694e+09
# 25        1638780.10  4.378514e+09
# 26        1614975.42  4.288309e+09
# 27        1630030.43  4.342939e+09
# 28        1268280.03  3.351770e+09
# 29        1251085.98  3.306936e+09
# 30         838022.55  1.098846e+09
# 31         899819.79  1.107106e+09
# 32         901699.28  1.117545e+09
# 33         778964.16  1.091448e+09
# 34         771606.97  1.079286e+09
# 35         953294.86  1.450089e+09
# 36        1046626.15  1.443241e+09
# 37        1050782.05  1.487515e+09
# 38         908191.03  1.527409e+09
# 39         904412.63  1.464806e+09
# 40         856462.44  1.327472e+09
# 41        1662284.48  5.364934e+09
# 42        1951177.31  6.283621e+09
# 43        1913580.98  6.167307e+09
# 44        1491673.53  4.826990e+09
# 45        1497018.05  4.834796e+09
# 46        1457972.52  4.711955e+09
# 47        1267600.14  2.228179e+09
# 48        1446723.81  2.535350e+09
# 49        1447400.47  2.556810e+09
# 50        1153750.34  2.026662e+09
# 51        1145907.53  2.012752e+09
# 52        1144218.56  2.009321e+09

# %%
# Plot LIKWID sample time-series for one subfolder/benchmark and one field
selected_subfolder = 'turbo-performance-0'
selected_benchmark = None  # None => auto-pick first benchmark found in selected_subfolder
selected_field = 'Power L3 [W]'

plot_likwid_timeseries(
    base_dir=base_dir,
    selected_subfolder=selected_subfolder,
    selected_benchmark=selected_benchmark,
    selected_field=selected_field,
    skip_initial=skip_initial,
    policy_name=policy_name,
    include_benchmark_in_title=True,
)
# Out:
# Removed 16 extreme-high samples from 'Power L3 [W]' using upper bound 704

# %%
plot_metrics = [
    'Total runtime [s]',
    'Average total power [W]',
    'Total energy [J]',
    'EDP [J*s]',
]

plot_benchmark_boxplots(
    per_benchmark_summary=per_benchmark_summary,
    policy_name=policy_name,
    plot_metrics=plot_metrics,
)
