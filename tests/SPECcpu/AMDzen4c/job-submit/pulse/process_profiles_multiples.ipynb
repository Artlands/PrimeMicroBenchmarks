# %% [markdown]
# # LIKWID policy-* summary
#
# Run this notebook from a policy folder such as `performance/` or `ondemand/`.
# It auto-detects subfolders like `<policy>-*` and computes:
# - Total runtime [s]
# - Average total power [W]
# - Total energy [J]
# - EDP [J*s]

# %%
from __future__ import annotations

from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# Settings
base_dir = Path('.')  # run from policy folder (e.g., performance/, ondemand/)
policy_name = base_dir.resolve().name
subfolder_pattern = f'{policy_name}-*'
benchmark_name = None  # None => process all detected benchmarks; set to a name to filter
skip_initial = 3
output_dir = base_dir  # per-benchmark CSV files are written here

# %%
import sys
from pathlib import Path

repo_root = None
for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents]:
    if (candidate / 'tests' / 'common' / 'process_profiles_lib.py').is_file():
        repo_root = candidate
        break

if repo_root is None:
    raise RuntimeError('Could not locate tests/common/process_profiles_lib.py from current notebook path')

lib_dir = repo_root / 'tests' / 'common'
if str(lib_dir) not in sys.path:
    sys.path.insert(0, str(lib_dir))

from process_profiles_lib import (
    SUM_FIELDS,
    build_policy_summary,
    extract_job_id,
    find_stdout_for_job,
    list_profiles,
    load_likwid_profile,
    newest_profile_for_benchmark,
    plot_benchmark_boxplots,
    plot_likwid_timeseries,
    print_policy_context,
    run_has_fatal_error,
    summarize_profile,
)

# %%
per_benchmark_summary, all_output = build_policy_summary(
    base_dir=base_dir,
    subfolder_pattern=subfolder_pattern,
    benchmark_name=benchmark_name,
    skip_initial=skip_initial,
    output_dir=output_dir,
    policy_name=policy_name,
)

print_policy_context(policy_name, subfolder_pattern, benchmark_name)
all_output
# Out:
# Removed 111 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-0/fotonik3d: found fatal error markers in speccpu_fotonik3d.38127.prof
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Removed 4 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 33 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-0/perlbench: found fatal error markers in speccpu_perlbench.38133.out
# Removed 36 extreme-high LIKWID samples using automatic power filtering
# Removed 175 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-0/x264: found fatal error markers in speccpu_x264.38136.prof
# Skipping pulse-0/xalancbmk: found fatal error markers in speccpu_xalancbmk.38137.out
# Removed 75 extreme-high LIKWID samples using automatic power filtering
# Removed 26 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 4 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-1/fotonik3d: found fatal error markers in speccpu_fotonik3d.38142.prof
# Removed 1 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 33 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-1/perlbench: found fatal error markers in speccpu_perlbench.38148.out
# Removed 37 extreme-high LIKWID samples using automatic power filtering
# Removed 249 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-1/x264: found fatal error markers in speccpu_x264.38151.prof
# Skipping pulse-1/xalancbmk: found fatal error markers in speccpu_xalancbmk.38152.out
# Removed 104 extreme-high LIKWID samples using automatic power filtering
# Removed 30 extreme-high LIKWID samples using automatic power filtering
# Removed 8 extreme-high LIKWID samples using automatic power filtering
# Removed 3 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-2/fotonik3d: found fatal error markers in speccpu_fotonik3d.38157.prof
# Removed 1 extreme-high LIKWID samples using automatic power filtering
# Removed 5 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 33 extreme-high LIKWID samples using automatic power filtering
# Removed 8 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-2/perlbench: found fatal error markers in speccpu_perlbench.38163.out
# Removed 37 extreme-high LIKWID samples using automatic power filtering
# Removed 132 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-2/x264: found fatal error markers in speccpu_x264.38166.prof
# Skipping pulse-2/xalancbmk: found fatal error markers in speccpu_xalancbmk.38167.out
# Removed 125 extreme-high LIKWID samples using automatic power filtering
# Removed 278 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 3 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-3/fotonik3d: found fatal error markers in speccpu_fotonik3d.38172.prof
# Removed 1 extreme-high LIKWID samples using automatic power filtering
# Removed 4 extreme-high LIKWID samples using automatic power filtering
# Removed 14 extreme-high LIKWID samples using automatic power filtering
# Removed 36 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-3/perlbench: found fatal error markers in speccpu_perlbench.38178.out
# Removed 37 extreme-high LIKWID samples using automatic power filtering
# Removed 180 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-3/x264: found fatal error markers in speccpu_x264.38181.prof
# Skipping pulse-3/xalancbmk: found fatal error markers in speccpu_xalancbmk.38182.out
# Removed 89 extreme-high LIKWID samples using automatic power filtering
# Removed 136 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 3 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-4/fotonik3d: found fatal error markers in speccpu_fotonik3d.38187.prof
# Removed 1 extreme-high LIKWID samples using automatic power filtering
# Removed 5 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 34 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-4/perlbench: found fatal error markers in speccpu_perlbench.38193.out
# Removed 37 extreme-high LIKWID samples using automatic power filtering
# Removed 130 extreme-high LIKWID samples using automatic power filtering
# Skipping pulse-4/x264: found fatal error markers in speccpu_x264.38196.prof
# Skipping pulse-4/xalancbmk: found fatal error markers in speccpu_xalancbmk.38197.out
# Removed 71 extreme-high LIKWID samples using automatic power filtering
# [cam4] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_cam4.csv
# [deepsjeng] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_deepsjeng.csv
# [exchange2] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_exchange2.csv
# [gcc] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_gcc.csv
# [leela] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_leela.csv
# [mcf] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_mcf.csv
# [nab] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_nab.csv
# [omnetpp] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_omnetpp.csv
# [pop2] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_pop2.csv
# [wrf] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_wrf.csv
# [xz] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/pulse/pulse_summary_xz.csv
# Policy folder: pulse
# Subfolder pattern: pulse-*
# Benchmark filter: all detected benchmarks
#    subfolder benchmark  Total runtime [s]  Average total power [W]  \
# 0    Average      cam4            3996.73                   433.67
# 1    pulse-0      cam4            3990.85                   439.82
# 2    pulse-1      cam4            4017.00                   424.98
# 3    pulse-2      cam4            3996.93                   428.04
# 4    pulse-3      cam4            3997.42                   438.12
# ..       ...       ...                ...                      ...
# 61   pulse-0        xz            2183.70                   471.71
# 62   pulse-1        xz            2183.70                   477.54
# 63   pulse-2        xz            2181.30                   481.09
# 64   pulse-3        xz            2171.66                   480.97
# 65   pulse-4        xz            2189.15                   472.49
#
#     Total energy [J]     EDP [J*s]
# 0         1734981.15  6.934093e+09
# 1         1757481.65  7.013850e+09
# 2         1706625.11  6.855508e+09
# 3         1710326.18  6.836054e+09
# 4         1757343.68  7.024843e+09
# ..               ...           ...
# 61        1031433.20  2.252339e+09
# 62        1043422.64  2.278527e+09
# 63        1050727.75  2.291954e+09
# 64        1045378.47  2.270211e+09
# 65        1034772.10  2.265270e+09
#
# [66 rows x 6 columns]

# %%
# Plot LIKWID sample time-series for one subfolder/benchmark and one field
selected_subfolder = 'pulse-0'
selected_benchmark = 'gcc'  # None => auto-pick first benchmark found in selected_subfolder
# selected_field = 'Power L3 [W]'
selected_field = 'Clock [MHz]'

plot_likwid_timeseries(
    base_dir=base_dir,
    selected_subfolder=selected_subfolder,
    selected_benchmark=selected_benchmark,
    selected_field=selected_field,
    skip_initial=skip_initial,
    policy_name=policy_name,
    include_benchmark_in_title=True,
)
# Out:
# Removed 16 extreme-high samples from 'Clock [MHz]' using upper bound 2.25e+03

# %%
plot_metrics = [
    'Total runtime [s]',
    'Average total power [W]',
    'Total energy [J]',
    'EDP [J*s]',
]

plot_benchmark_boxplots(
    per_benchmark_summary=per_benchmark_summary,
    policy_name=policy_name,
    plot_metrics=plot_metrics,
)
