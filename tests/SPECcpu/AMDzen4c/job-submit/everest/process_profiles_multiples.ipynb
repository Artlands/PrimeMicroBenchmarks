# %% [markdown]
# # LIKWID policy-* summary
#
# Run this notebook from a policy folder such as `performance/` or `ondemand/`.
# It auto-detects subfolders like `<policy>-*` and computes:
# - Total runtime [s]
# - Average total power [W]
# - Total energy [J]
# - EDP [J*s]

# %%
from __future__ import annotations

from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd

# Settings
base_dir = Path('.')  # run from policy folder (e.g., performance/, ondemand/)
policy_name = base_dir.resolve().name
subfolder_pattern = f'{policy_name}-*'
benchmark_name = None  # None => process all detected benchmarks; set to a name to filter
skip_initial = 3
output_dir = base_dir  # per-benchmark CSV files are written here

# %%
import sys
from pathlib import Path

repo_root = None
for candidate in [Path.cwd().resolve(), *Path.cwd().resolve().parents]:
    if (candidate / 'tests' / 'common' / 'process_profiles_lib.py').is_file():
        repo_root = candidate
        break

if repo_root is None:
    raise RuntimeError('Could not locate tests/common/process_profiles_lib.py from current notebook path')

lib_dir = repo_root / 'tests' / 'common'
if str(lib_dir) not in sys.path:
    sys.path.insert(0, str(lib_dir))

from process_profiles_lib import (
    SUM_FIELDS,
    build_policy_summary,
    extract_job_id,
    find_stdout_for_job,
    list_profiles,
    load_likwid_profile,
    newest_profile_for_benchmark,
    plot_benchmark_boxplots,
    plot_likwid_timeseries,
    print_policy_context,
    run_has_fatal_error,
    summarize_profile,
)

# %%
per_benchmark_summary, all_output = build_policy_summary(
    base_dir=base_dir,
    subfolder_pattern=subfolder_pattern,
    benchmark_name=benchmark_name,
    skip_initial=skip_initial,
    output_dir=output_dir,
    policy_name=policy_name,
)

print_policy_context(policy_name, subfolder_pattern, benchmark_name)
all_output
# Out:
# Removed 65 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-0/fotonik3d: found fatal error markers in speccpu_fotonik3d.37946.prof
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Removed 5 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 33 extreme-high LIKWID samples using automatic power filtering
# Removed 5 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-0/perlbench: found fatal error markers in speccpu_perlbench.37952.out
# Removed 36 extreme-high LIKWID samples using automatic power filtering
# Removed 28 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-0/x264: found fatal error markers in speccpu_x264.37955.prof
# Skipping everest-0/xalancbmk: found fatal error markers in speccpu_xalancbmk.37956.out
# Removed 14 extreme-high LIKWID samples using automatic power filtering
# Removed 26 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-1/fotonik3d: found fatal error markers in speccpu_fotonik3d.37961.prof
# Removed 1 extreme-high LIKWID samples using automatic power filtering
# Removed 5 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 33 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-1/perlbench: found fatal error markers in speccpu_perlbench.37967.out
# Removed 37 extreme-high LIKWID samples using automatic power filtering
# Removed 28 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-1/x264: found fatal error markers in speccpu_x264.37970.prof
# Skipping everest-1/xalancbmk: found fatal error markers in speccpu_xalancbmk.37971.out
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# Removed 27 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-2/fotonik3d: found fatal error markers in speccpu_fotonik3d.37976.prof
# Removed 1 extreme-high LIKWID samples using automatic power filtering
# Removed 4 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 34 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-2/perlbench: found fatal error markers in speccpu_perlbench.37982.out
# Removed 36 extreme-high LIKWID samples using automatic power filtering
# Removed 27 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-2/x264: found fatal error markers in speccpu_x264.37985.prof
# Skipping everest-2/xalancbmk: found fatal error markers in speccpu_xalancbmk.37986.out
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# Removed 55 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 4 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-3/fotonik3d: found fatal error markers in speccpu_fotonik3d.37991.prof
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 34 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-3/perlbench: found fatal error markers in speccpu_perlbench.37997.out
# Removed 39 extreme-high LIKWID samples using automatic power filtering
# Removed 28 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-3/x264: found fatal error markers in speccpu_x264.38000.prof
# Skipping everest-3/xalancbmk: found fatal error markers in speccpu_xalancbmk.38001.out
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# Removed 26 extreme-high LIKWID samples using automatic power filtering
# Removed 7 extreme-high LIKWID samples using automatic power filtering
# Removed 2 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-4/fotonik3d: found fatal error markers in speccpu_fotonik3d.38006.prof
# Removed 5 extreme-high LIKWID samples using automatic power filtering
# Removed 12 extreme-high LIKWID samples using automatic power filtering
# Removed 32 extreme-high LIKWID samples using automatic power filtering
# Removed 6 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-4/perlbench: found fatal error markers in speccpu_perlbench.38012.out
# Removed 37 extreme-high LIKWID samples using automatic power filtering
# Removed 28 extreme-high LIKWID samples using automatic power filtering
# Skipping everest-4/x264: found fatal error markers in speccpu_x264.38015.prof
# Skipping everest-4/xalancbmk: found fatal error markers in speccpu_xalancbmk.38016.out
# Removed 16 extreme-high LIKWID samples using automatic power filtering
# [cam4] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_cam4.csv
# [deepsjeng] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_deepsjeng.csv
# [exchange2] Detected abnormal runs with extreme-high values (excluded from plots/averages/csv): everest-3
# [exchange2] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_exchange2.csv
# [gcc] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_gcc.csv
# [leela] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_leela.csv
# [mcf] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_mcf.csv
# [nab] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_nab.csv
# [omnetpp] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_omnetpp.csv
# [pop2] Detected abnormal runs with extreme-high values (excluded from plots/averages/csv): everest-3
# [pop2] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_pop2.csv
# [wrf] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_wrf.csv
# [xz] Wrote: /mnt/REPACSS/home/li29729/Research2025/CPUfreq/PrimeMicroBenchmarks/tests/SPECcpu/AMDzen4c/job-submit/everest/everest_summary_xz.csv
# Policy folder: everest
# Subfolder pattern: everest-*
# Benchmark filter: all detected benchmarks
#     subfolder benchmark  Total runtime [s]  Average total power [W]  \
# 0     Average      cam4            3958.24                   447.83
# 1   everest-0      cam4            3955.52                   437.54
# 2   everest-1      cam4            3955.98                   451.64
# 3   everest-2      cam4            3948.68                   445.03
# 4   everest-3      cam4            3966.20                   452.03
# ..        ...       ...                ...                      ...
# 59  everest-0        xz            2361.63                   425.83
# 60  everest-1        xz            2366.11                   428.77
# 61  everest-2        xz            2353.57                   423.93
# 62  everest-3        xz            2336.96                   437.74
# 63  everest-4        xz            2320.92                   437.11
#
#     Total energy [J]     EDP [J*s]
# 0         1772614.65  7.016552e+09
# 1         1731264.53  6.848046e+09
# 2         1786171.86  7.066054e+09
# 3         1756689.72  6.936613e+09
# 4         1793699.92  7.114170e+09
# ..               ...           ...
# 59        1005253.15  2.374035e+09
# 60        1013887.50  2.398968e+09
# 61         997306.09  2.347233e+09
# 62        1022266.24  2.388995e+09
# 63        1014284.11  2.354077e+09
#
# [64 rows x 6 columns]

# %%
# Plot LIKWID sample time-series for one subfolder/benchmark and one field
selected_subfolder = 'everest-0'
selected_benchmark = None  # None => auto-pick first benchmark found in selected_subfolder
selected_field = 'Power L3 [W]'

plot_likwid_timeseries(
    base_dir=base_dir,
    selected_subfolder=selected_subfolder,
    selected_benchmark=selected_benchmark,
    selected_field=selected_field,
    skip_initial=skip_initial,
    policy_name=policy_name,
    include_benchmark_in_title=True,
)
# Out:
# Removed 59 extreme-high samples from 'Power L3 [W]' using upper bound 531

# %%
plot_metrics = [
    'Total runtime [s]',
    'Average total power [W]',
    'Total energy [J]',
    'EDP [J*s]',
]

plot_benchmark_boxplots(
    per_benchmark_summary=per_benchmark_summary,
    policy_name=policy_name,
    plot_metrics=plot_metrics,
)
