# %% [markdown]
# # Process micro-benchmark outputs
#
# This notebook extracts Loop time values from the organized files in `apps/<benchmark>/`.
# By default it uses `dvfs` outputs; change `group` to `energy` to switch.

# %%
from pathlib import Path
import re

group = 'energy'  # change to 'energy' if needed
baseline_freq = '2.25GHz'
selected_freqs = ['1.5GHz', '1.8GHz', '2.25GHz']  # e.g., ['0.8GHz', '1.0GHz']; leave empty to use all

loop_time_re = re.compile(r'Loop time:\s*([0-9.]+)\s*seconds')
freq_re = re.compile(rf'_(?:{group})_([0-9.]+GHz)\.out$')

def find_apps_dir(start: Path) -> Path:
    current = start.resolve()
    for _ in range(6):
        candidate = current / 'apps'
        if candidate.is_dir():
            return candidate
        if current.parent == current:
            break
        current = current.parent
    raise FileNotFoundError('No apps directory found. Run from repo root or set apps_dir manually.')

apps_dir = find_apps_dir(Path.cwd())

def parse_loop_time(path: Path):
    for line in path.read_text().splitlines():
        match = loop_time_re.search(line)
        if match:
            return float(match.group(1))
    return None

def extract_freq(path: Path):
    match = freq_re.search(path.name)
    if not match:
        return None
    return match.group(1)

def freq_value(freq: str):
    return float(freq.replace('GHz', ''))

raw_results = {}
perf_results = {}
missing_baseline = []
for app_dir in sorted(apps_dir.iterdir()):
    if not app_dir.is_dir():
        continue
    entries = []
    for out_file in sorted(app_dir.glob(f'*_{group}_*.out')):
        freq = extract_freq(out_file)
        if not freq:
            continue
        if selected_freqs and freq not in selected_freqs:
            continue
        loop_time = parse_loop_time(out_file)
        if loop_time is None:
            continue
        entries.append((freq, loop_time))
    if not entries:
        continue
    entries.sort(key=lambda item: freq_value(item[0]))
    raw_results[app_dir.name] = entries
    base = None
    for freq, time in entries:
        if freq == baseline_freq:
            base = time
            break
    if base is None:
        missing_baseline.append(app_dir.name)
        continue
    perf_entries = [(freq, base / time) for freq, time in entries]
    perf_results[app_dir.name] = perf_entries

perf_results
# Out:
# {'atomic_fight': [('1.5GHz', 0.25922794464499405),
#   ('1.8GHz', 0.3274828868390335),
#   ('2.25GHz', 1.0)],
#  'branch_mispredict': [('1.5GHz', 0.6651962954610088),
#   ('1.8GHz', 0.7961084065560882),
#   ('2.25GHz', 1.0)],
#  'dgemm': [('1.5GHz', 0.6809025069772484),
#   ('1.8GHz', 0.816126677501644),
#   ('2.25GHz', 1.0)],
#  'fft_mix': [('1.5GHz', 0.661734249213751),
#   ('1.8GHz', 0.7982316188133597),
#   ('2.25GHz', 1.0)],
#  'icache_thrash': [('1.5GHz', 0.6662272825958407),
#   ('1.8GHz', 0.8016086093845055),
#   ('2.25GHz', 1.0)],
#  'io_write': [('1.5GHz', 0.09316065497214125),
#   ('1.8GHz', 0.13716840768385413),
#   ('2.25GHz', 1.0)],
#  'l3_stencil': [('1.5GHz', 0.8121530736967219),
#   ('1.8GHz', 0.8764783619228691),
#   ('2.25GHz', 1.0)],
#  'mpi_bandwidth': [('1.5GHz', 1.002054345604124),
#   ('1.8GHz', 1.0033409246774003),
#   ('2.25GHz', 1.0)],
#  'mpi_barrier': [('1.5GHz', 0.7905491797371816),
#   ('1.8GHz', 0.8552541920177175),
#   ('2.25GHz', 1.0)],
#  'pointer_chase': [('1.5GHz', 0.8945244008870992),
#   ('1.8GHz', 1.0007576992732177),
#   ('2.25GHz', 1.0)],
#  'spmv': [('1.5GHz', 0.9271375009239802),
#   ('1.8GHz', 0.9457979275470486),
#   ('2.25GHz', 1.0)],
#  'stream': [('1.5GHz', 0.9943764568638221),
#   ('1.8GHz', 0.9937585999321885),
#   ('2.25GHz', 1.0)],
#  'tree_walk': [('1.5GHz', 0.8414416412345959),
#   ('1.8GHz', 0.9059709044966276),
#   ('2.25GHz', 1.0)]}

# %%
# Energy profile helpers (from process_apps_energy.ipynb)
from pathlib import Path
from typing import Dict, List, Sequence
import pandas as pd

SUM_FIELDS = {
    "Energy [J]",
    "Power [W]",
    "Energy PP0 [J]",
    "Power PP0 [W]",
    "Energy DRAM [J]",
    "Power DRAM [W]",
    "Energy PLATFORM [J]",
    "Power PLATFORM [W]",
    "Memory read bandwidth [MBytes/s]",
    "Memory read data volume [GBytes]",
    "Memory write bandwidth [MBytes/s]",
    "Memory write data volume [GBytes]",
    "Memory bandwidth [MBytes/s]",
    "Memory data volume [GBytes]",
    "L3 request rate",
    "L3 miss rate",
    "L3 miss ratio",
    "Energy Core [J]",
    "Power Core [W]",
    "Energy L3 [J]",
    "Power L3 [W]",
}

def find_apps_dir(start: Path) -> Path:
    current = start.resolve()
    for _ in range(6):
        candidate = current / 'apps'
        if candidate.is_dir():
            return candidate
        if current.parent == current:
            break
        current = current.parent
    raise FileNotFoundError('No apps directory found. Run from repo root or set apps_dir manually.')

def parse_headers(stdout_path: Path) -> List[Sequence[str]]:
    headers: List[Sequence[str]] = []
    with stdout_path.open() as handle:
        for line in handle:
            if line.startswith('# GID|'):
                parts = line.lstrip('#').strip().split('|')
                fields = parts[3:]
                if fields:
                    headers.append(fields)
    if not headers:
        raise RuntimeError(f'No LIKWID headers found in {stdout_path}')
    return headers

def aggregate_metric(values: Sequence[float], field: str) -> float:
    if not values:
        raise KeyError(f'Missing values for field {field}')
    if field in SUM_FIELDS:
        return float(sum(values))
    return float(sum(values) / len(values))

def load_energy_profile(app: str, freq: str, *, apps_dir: Path | None = None, group: str = 'energy') -> pd.DataFrame:
    if apps_dir is None:
        apps_dir = find_apps_dir(Path.cwd())

    out_path = apps_dir / app / f'{app}_{group}_{freq}.out'
    prof_path = apps_dir / app / f'{app}_{group}_{freq}.prof'
    if not out_path.exists():
        raise FileNotFoundError(f'Missing header file: {out_path}')
    if not prof_path.exists():
        raise FileNotFoundError(f'Missing profile file: {prof_path}')

    headers = parse_headers(out_path)
    if len(headers) != 1:
        print(f'Warning: expected 1 header set, found {len(headers)} in {out_path.name}')
    header = headers[0]
    global_field = header[0]
    metric_fields = header[1:]

    rows: List[Dict[str, float]] = []
    in_loop = False
    saw_start = False
    saw_end = False

    with prof_path.open() as handle:
        for raw_line in handle:
            line = raw_line.strip()
            if not line:
                continue
            if line.startswith('LOOP_START_REL'):
                in_loop = True
                saw_start = True
                continue
            if line.startswith('LOOP_END_REL'):
                in_loop = False
                saw_end = True
                break
            if not in_loop:
                continue
            if line.startswith('#'):
                continue
            parts = line.split(',')
            if len(parts) < 4:
                continue
            gid = int(parts[0])
            metrics_count = int(parts[1])
            cpu_count = int(parts[2])
            values = [float(val) for val in parts[3:]]

            if metrics_count != len(metric_fields):
                raise ValueError(
                    f'Header mismatch: expected {len(metric_fields)} metrics, got {metrics_count} in {prof_path.name}'
                )

            expected_values = 1 + metrics_count * cpu_count
            if len(values) != expected_values:
                raise ValueError(
                    f'Expected {expected_values} numeric entries, got {len(values)} in {prof_path.name}'
                )

            global_value = values[0]
            metric_values = values[1:]

            extracted: Dict[str, float] = {global_field: global_value}
            for idx, field in enumerate(metric_fields):
                start = idx * cpu_count
                end = start + cpu_count
                segment = metric_values[start:end]
                if not segment:
                    continue
                extracted[field] = aggregate_metric(segment, field)

            extracted['gid'] = gid
            rows.append(extracted)

    if not saw_start:
        raise RuntimeError(f'LOOP_START_REL marker not found in {prof_path.name}')
    if not saw_end:
        raise RuntimeError(f'LOOP_END_REL marker not found in {prof_path.name}')
    if not rows:
        raise RuntimeError(f'No samples found between loop markers in {prof_path.name}')

    return pd.DataFrame(rows)

def clean_abnormal(df: pd.DataFrame, *, z_thresh: float = 8.0, cols: list[str] | None = None) -> pd.DataFrame:
    numeric_cols = [c for c in df.columns if c != "gid"]
    if cols is None:
        cols = numeric_cols
    cleaned = df.copy()
    for col in cols:
        if col not in cleaned.columns:
            continue
        series = cleaned[col]
        median = series.median()
        mad = (series - median).abs().median()
        if mad == 0 or series.isna().all():
            continue
        robust_z = (series - median).abs() / (1.4826 * mad)
        mask = robust_z > z_thresh
        if mask.any():
            cleaned.loc[mask, col] = pd.NA
            cleaned[col] = cleaned[col].ffill().bfill()
    return cleaned

# %%
# Total energy per benchmark/frequency (within LOOP_START_REL/LOOP_END_REL)
from pathlib import Path
import re

energy_group = 'energy'
power_field = 'Power L3 [W]'
energy_freq_re = re.compile(rf'_(?:{energy_group})_([0-9.]+GHz)\.out$')

apps_dir = find_apps_dir(Path.cwd())

def extract_energy_freq(path: Path):
    match = energy_freq_re.search(path.name)
    if not match:
        return None
    return match.group(1)

energy_raw = {}
energy_results = {}
missing_energy_baseline = []
for app_dir in sorted(apps_dir.iterdir()):
    if not app_dir.is_dir():
        continue
    entries = []
    for out_file in sorted(app_dir.glob(f'*_{energy_group}_*.out')):
        freq = extract_energy_freq(out_file)
        if not freq:
            continue
        if selected_freqs and freq not in selected_freqs:
            continue
        df = load_energy_profile(app_dir.name, freq, apps_dir=apps_dir, group=energy_group)
        df = clean_abnormal(df)
        if power_field not in df.columns:
            raise KeyError(f'Missing {power_field} in {app_dir.name} {freq}')
        time_field = df.columns[0]
        if time_field == 'gid':
            raise KeyError('Time field not found in energy profile data')
        times = df[time_field].to_numpy()
        powers = df[power_field].to_numpy()
        if len(times) < 2:
            raise RuntimeError(f'Not enough samples to integrate power for {app_dir.name} {freq}')
        deltas = times[1:] - times[:-1]
        total_energy = float((powers[:-1] * deltas).sum())
        entries.append((freq, total_energy))
    if not entries:
        continue
    entries.sort(key=lambda item: freq_value(item[0]))
    energy_raw[app_dir.name] = entries
    base = None
    for freq, energy in entries:
        if freq == baseline_freq:
            base = energy
            break
    if base is None:
        missing_energy_baseline.append(app_dir.name)
        continue
    rel_entries = [(freq, energy / base) for freq, energy in entries]
    energy_results[app_dir.name] = rel_entries

energy_results
# Out:
# {'atomic_fight': [('1.5GHz', 3.427491968636222),
#   ('1.8GHz', 4.739637062303342),
#   ('2.25GHz', 1.0)],
#  'branch_mispredict': [('1.5GHz', 1.084338539416773),
#   ('1.8GHz', 1.0534296338251687),
#   ('2.25GHz', 1.0)],
#  'dgemm': [('1.5GHz', 1.0154726155805893),
#   ('1.8GHz', 0.9949463101659308),
#   ('2.25GHz', 1.0)],
#  'fft_mix': [('1.5GHz', 1.0115654623932384),
#   ('1.8GHz', 1.0028162489761143),
#   ('2.25GHz', 1.0)],
#  'icache_thrash': [('1.5GHz', 1.0182328444845021),
#   ('1.8GHz', 1.042207043056828),
#   ('2.25GHz', 1.0)],
#  'io_write': [('1.5GHz', 9.53100077401268),
#   ('1.8GHz', 6.826245407850807),
#   ('2.25GHz', 1.0)],
#  'l3_stencil': [('1.5GHz', 1.0927772059598708),
#   ('1.8GHz', 1.0617264459080877),
#   ('2.25GHz', 1.0)],
#  'mpi_bandwidth': [('1.5GHz', 0.6818458881845233),
#   ('1.8GHz', 0.8027536649199268),
#   ('2.25GHz', 1.0)],
#  'mpi_barrier': [('1.5GHz', 0.8873730420799902),
#   ('1.8GHz', 0.9661758455563256),
#   ('2.25GHz', 1.0)],
#  'pointer_chase': [('1.5GHz', 0.985899612654841),
#   ('1.8GHz', 1.0193025032652223),
#   ('2.25GHz', 1.0)],
#  'spmv': [('1.5GHz', 0.925944472759126),
#   ('1.8GHz', 0.9483523094751586),
#   ('2.25GHz', 1.0)],
#  'stream': [('1.5GHz', 0.8517729996414409),
#   ('1.8GHz', 0.9237732582890938),
#   ('2.25GHz', 1.0)],
#  'tree_walk': [('1.5GHz', 1.0358641596206282),
#   ('1.8GHz', 1.041540334325558),
#   ('2.25GHz', 1.0)]}

# %%
# Example: plot a single benchmark
import matplotlib.pyplot as plt

# app = next(iter(perf_results)) if perf_results else None
app = 'io_write'  # specify benchmark name here
if app:
    freqs = [float(f.replace('GHz', '')) for f, _ in perf_results[app]]
    labels = [f for f, _ in perf_results[app]]
    perf = [p for _, p in perf_results[app]]

    plt.figure(figsize=(6, 4))
    plt.plot(freqs, perf, marker='o')
    plt.title(f'Relative performance vs frequency: {app} ({group})')
    plt.xlabel('Frequency (GHz)')
    plt.ylabel(f'Performance relative to {baseline_freq}')
    plt.xticks(freqs, labels, rotation=45)
    plt.ylim(0, 1)
    plt.tight_layout()
    plt.show()

# %%
# Benchmark groups (edit these lists to control selection)
run_fast = [
    'dgemm',
    'branch_mispredict',
    'icache_thrash',
    # 'tree_walk',
    'fft_mix',
]

feed_me = [
    'l3_stencil',
    'stream',
    'spmv',
]

system_group = [
    'pointer_chase',
    'atomic_fight',
    'mpi_bandwidth',
]

sleep_group = [
    'mpi_barrier',
    'io_write',
]

# selected = []  # e.g., ['atomic_fight', 'dgemm']; leave empty to plot all
selected = run_fast + feed_me + system_group + sleep_group

# %%
import math

apps = list(perf_results.keys())
if selected:
    apps = [app for app in selected if app in perf_results]

if apps:
    cols = 4
    rows = math.ceil(len(apps) / cols)
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 5, rows * 4))
    axes = axes if isinstance(axes, (list, tuple)) else axes.flatten()

    for ax, app in zip(axes, apps):
        freqs = [float(f.replace('GHz', '')) for f, _ in perf_results[app]]
        labels = [f for f, _ in perf_results[app]]
        perf = [p for _, p in perf_results[app]]
        ax.plot(freqs, perf, marker='o')
        ax.set_title(app)
        ax.set_xlabel('Frequency (GHz)')
        ax.set_ylabel(f'Performance relative to {baseline_freq}')
        ax.set_xticks(freqs, labels, rotation=45)
        ax.set_ylim(0, 1)

    for ax in axes[len(apps):]:
        ax.axis('off')

    fig.suptitle('Relative performance vs frequency', y=1.02)
    fig.tight_layout()
    plt.show()

# %%
# Plot relative performance (left axis) and average power (right axis)
import math
import matplotlib.pyplot as plt

apps = sorted(set(perf_results.keys()) & set(raw_results.keys()))
if 'selected' in globals() and selected:
    apps = [app for app in selected if app in perf_results and app in raw_results]

def build_lookup(pairs):
    return {freq: value for freq, value in pairs}

if apps:
    cols = 4
    rows = math.ceil(len(apps) / cols)
    fig, axes = plt.subplots(rows, cols, figsize=(cols * 6, rows * 4))
    axes = axes if isinstance(axes, (list, tuple)) else axes.flatten()

    for ax, app in zip(axes, apps):
        perf_map = build_lookup(perf_results[app])
        raw_time_map = build_lookup(raw_results[app])
        perf_freqs = sorted(perf_map.keys(), key=freq_value)
        if not perf_freqs:
            ax.axis('off')
            continue
        x_perf = [float(f.replace('GHz', '')) for f in perf_freqs]
        ax.plot(x_perf, [perf_map[f] for f in perf_freqs], marker='o', color='tab:blue')
        ax.set_title(app)
        ax.set_xlabel('Frequency (GHz)')
        ax.set_ylabel(f'Relative performance to {baseline_freq}', color='tab:blue')
        ax.set_xticks(x_perf, perf_freqs, rotation=45)
        ax.set_ylim(0, 1.1)
        ax.tick_params(axis='y', labelcolor='tab:blue')

        if app in energy_raw:
            energy_map = build_lookup(energy_raw[app])
            power_freqs = [f for f in perf_freqs if f in energy_map and f in raw_time_map]
            if power_freqs:
                x_power = [float(f.replace('GHz', '')) for f in power_freqs]
                avg_power = [energy_map[f] / raw_time_map[f] for f in power_freqs]
                ax2 = ax.twinx()
                ax2.plot(x_power, avg_power, marker='s', color='tab:red')
                ax2.set_ylabel('Average power (W)', color='tab:red')
                ax2.set_ylim(0, 800)
                ax2.tick_params(axis='y', labelcolor='tab:red')

    for ax in axes[len(apps):]:
        ax.axis('off')

    fig.suptitle('Relative performance and average power vs frequency', y=1.02)
    fig.tight_layout()
    plt.show()

# %%
# Side-by-side app comparison setup
selected_side_by_side_apps = ['dgemm', 'mpi_bandwidth']

# %%
# Plot dgemm and mpi_bandwidth side by side
# Relative performance is shown with a dashed line.
import matplotlib.pyplot as plt

apps_to_plot = [
    app for app in selected_side_by_side_apps
    if app in perf_results and app in raw_results and app in energy_raw
]

def build_lookup(pairs):
    return {freq: value for freq, value in pairs}

if apps_to_plot:
    plt.rcParams.update({
        'font.size': 18,
        'axes.labelsize': 18,
        'xtick.labelsize': 18,
        'ytick.labelsize': 18,
        'legend.fontsize': 15,
    })

    fig, axes = plt.subplots(1, len(apps_to_plot), figsize=(8 * len(apps_to_plot), 5.5), squeeze=False)
    axes = axes.flatten()

    for ax, app in zip(axes, apps_to_plot):
        perf_map = build_lookup(perf_results[app])
        raw_time_map = build_lookup(raw_results[app])
        energy_map = build_lookup(energy_raw[app])

        freqs = sorted(set(perf_map) & set(raw_time_map) & set(energy_map), key=freq_value)
        if not freqs:
            ax.axis('off')
            continue

        x = [float(f.replace('GHz', '')) for f in freqs]
        rel_perf = [perf_map[f] for f in freqs]
        avg_power = [energy_map[f] / raw_time_map[f] for f in freqs]

        perf_line = ax.plot(
            x, rel_perf, marker='o', linestyle='--', color='tab:blue',
            label=f'{app}: Performance'
        )[0]

        ax.set_xlabel('Frequency (GHz)')
        ax.set_ylabel(f'Relative performance to 2.25GHz')
        ax.set_xticks(x, freqs, rotation=0)
        ax.set_ylim(0, 1.1)
        ax.grid(True, which='major', linestyle='--', linewidth=0.9, alpha=0.9)

        ax2 = ax.twinx()
        power_line = ax2.plot(
            x, avg_power, marker='s', linestyle='-', color='tab:red',
            label=f'{app}: CPU Power'
        )[0]
        ax2.set_ylabel('CPU Power (W)')
        ax2.grid(False)

        ax2.set_ylim(400, 800)

        ax.legend(
            [perf_line, power_line],
            [perf_line.get_label(), power_line.get_label()],
            loc='upper center',
            bbox_to_anchor=(0.5, 1.14),
            frameon=False,
            ncol=2,
        )

    fig.tight_layout(rect=[0, 0, 1, 1])
    plt.savefig('performance_pwr_dgemm_mpi.pdf', dpi=300)
    plt.show()
else:
    print('No matching data for selected_side_by_side_apps.')

# %%
# Find best frequency for lowest energy and lowest EDP
import pandas as pd

def build_lookup(pairs):
    return {freq: value for freq, value in pairs}

apps = sorted(set(raw_results.keys()) & set(energy_raw.keys()))
if 'selected' in globals() and selected:
    apps = [app for app in selected if app in raw_results and app in energy_raw]

rows = []
for app in apps:
    time_map = build_lookup(raw_results[app])
    energy_map = build_lookup(energy_raw[app])
    freqs = sorted(set(time_map) & set(energy_map), key=freq_value)
    if not freqs:
        continue
    energy_vals = {f: energy_map[f] for f in freqs}
    edp_vals = {f: energy_map[f] * time_map[f] for f in freqs}
    best_energy_freq = min(energy_vals, key=energy_vals.get)
    best_edp_freq = min(edp_vals, key=edp_vals.get)
    rows.append({
        'app': app,
        'best_energy_freq': best_energy_freq,
        'energy_j': energy_vals[best_energy_freq],
        'runtime_s': time_map[best_energy_freq],
        'best_edp_freq': best_edp_freq,
        'edp_j_s': edp_vals[best_edp_freq],
    })

best_freqs = pd.DataFrame(rows).sort_values('app')
best_freqs
# Out:
#                   app best_energy_freq       energy_j   runtime_s  \
# 8        atomic_fight          2.25GHz    7142.685983   27.147211
# 1   branch_mispredict          2.25GHz   26245.810868   56.960961
# 0               dgemm           1.8GHz   96969.356875  160.226147
# 3             fft_mix          2.25GHz   41976.675213   66.189290
# 2       icache_thrash          2.25GHz    3834.854728    7.306426
# 11           io_write          2.25GHz   27155.807136  110.174400
# 4          l3_stencil          2.25GHz  146308.665265  525.992383
# 9       mpi_bandwidth           1.5GHz  246370.103603  533.444323
# 10        mpi_barrier           1.5GHz  153549.772367  412.065185
# 7       pointer_chase           1.5GHz   33582.974207  109.144495
# 6                spmv           1.5GHz   82061.099772  213.803276
# 5              stream           1.5GHz  125056.341809  343.616107
#
#    best_edp_freq       edp_j_s
# 8        2.25GHz  1.939040e+05
# 1        2.25GHz  1.494987e+06
# 0        2.25GHz  1.274459e+07
# 3        2.25GHz  2.778406e+06
# 2        2.25GHz  2.801908e+04
# 11       2.25GHz  2.991875e+06
# 4        2.25GHz  7.695724e+07
# 9         1.5GHz  1.314247e+08
# 10       2.25GHz  5.636867e+07
# 7        2.25GHz  3.325680e+06
# 6         1.5GHz  1.754493e+07
# 5         1.5GHz  4.297137e+07

# %%
# Build frequency label dictionaries from best_freqs
FREQ_LABELS = {
    'HighFreq': '2.25GHz',
    'MedFreq': '1.8GHz',
    'LowFreq': '1.5GHz',
}

LABELS = {label: set() for label in FREQ_LABELS}

for _, row in best_freqs.iterrows():
    freq = row['best_energy_freq']
    label = next((k for k, v in FREQ_LABELS.items() if v == freq), None)
    if label:
        LABELS[label].add(row['app'])

LABELS
# Out:
# {'HighFreq': {'atomic_fight',
#   'branch_mispredict',
#   'fft_mix',
#   'icache_thrash',
#   'io_write',
#   'l3_stencil'},
#  'MedFreq': {'dgemm'},
#  'LowFreq': {'mpi_bandwidth',
#   'mpi_barrier',
#   'pointer_chase',
#   'spmv',
#   'stream'}}

# %%
# Build frequency label dictionaries from best_edp_freq
FREQ_LABELS = {
    'HighFreq': '2.25GHz',
    'MedFreq': '1.8GHz',
    'LowFreq': '1.5GHz',
}

EDP_LABELS = {label: set() for label in FREQ_LABELS}

for _, row in best_freqs.iterrows():
    freq = row['best_edp_freq']
    label = next((k for k, v in FREQ_LABELS.items() if v == freq), None)
    if label:
        EDP_LABELS[label].add(row['app'])

EDP_LABELS
# Out:
# {'HighFreq': {'atomic_fight',
#   'branch_mispredict',
#   'dgemm',
#   'fft_mix',
#   'icache_thrash',
#   'io_write',
#   'l3_stencil',
#   'mpi_barrier',
#   'pointer_chase'},
#  'MedFreq': set(),
#  'LowFreq': {'mpi_bandwidth', 'spmv', 'stream'}}

# %%
# # Load average CPU/DRAM/System power from *_job_ids_metrics.json
# import json
# import pandas as pd

# METRIC_MAP = {
#     "cpu": "idrac.cpupower",
#     "dram": "idrac.totalmemorypower",
#     "system": "idrac.systempowerconsumption",
# }



# def find_metrics_apps_dir(start: Path) -> Path:
#     current = start.resolve()
#     for _ in range(8):
#         candidate = current / "scripts" / "AMDzen4c" / "apps"
#         if candidate.is_dir():
#             return candidate
#         if current.parent == current:
#             break
#         current = current.parent
#     # fallback to existing apps_dir path
#     return find_apps_dir(start)

# def _points_to_df(points):
#     df = pd.DataFrame(points)
#     if df.empty:
#         return pd.DataFrame(columns=["time", "value"])
#     df["time"] = pd.to_datetime(df["time"], errors="coerce")
#     df["value"] = pd.to_numeric(df["value"], errors="coerce")
#     df = df.dropna(subset=["time", "value"]).sort_values("time")
#     return df


# def _merge_cpu_sockets_avg(series_list, tolerance="1min"):
#     s1 = next((s for s in series_list if s.get("label") == "CPU.Socket.1"), None)
#     s2 = next((s for s in series_list if s.get("label") == "CPU.Socket.2"), None)

#     if s1 is None and s2 is None:
#         return None
#     if s1 is None:
#         df = _points_to_df(s2.get("points", [])).rename(columns={"value": "power"})
#         return None if df.empty else float(df["power"].mean())
#     if s2 is None:
#         df = _points_to_df(s1.get("points", [])).rename(columns={"value": "power"})
#         return None if df.empty else float(df["power"].mean())

#     df1 = _points_to_df(s1.get("points", [])).rename(columns={"value": "p1"})
#     df2 = _points_to_df(s2.get("points", [])).rename(columns={"value": "p2"})
#     if df1.empty and df2.empty:
#         return None
#     if df1.empty:
#         return float(df2["p2"].mean())
#     if df2.empty:
#         return float(df1["p1"].mean())

#     left, right = (df1, df2) if len(df1) >= len(df2) else (df2, df1)
#     merged = pd.merge_asof(
#         left.sort_values("time"),
#         right.sort_values("time"),
#         on="time",
#         direction="nearest",
#         tolerance=pd.Timedelta(tolerance),
#     )
#     merged = merged.dropna(subset=["p1", "p2"], how="all")
#     if merged.empty:
#         return None
#     merged["power"] = merged[["p1", "p2"]].fillna(0.0).sum(axis=1)
#     return float(merged["power"].mean())


# def _single_series_avg(series_list, label="PowerMetrics"):
#     target = next((s for s in series_list if s.get("label") == label), None)
#     if target is None and series_list:
#         target = series_list[0]
#     if target is None:
#         return None
#     df = _points_to_df(target.get("points", []))
#     if df.empty:
#         return None
#     return float(df["value"].mean())


# def load_avg_powers_from_metrics(apps_dir, group="energy", selected_freqs=None, tolerance="1min"):
#     avg_power = {}
#     for app_dir in sorted(apps_dir.iterdir()):
#         if not app_dir.is_dir():
#             continue
#         metrics_path = app_dir / f"{app_dir.name}_job_ids_metrics.json"
#         if not metrics_path.exists():
#             continue

#         payload = json.loads(metrics_path.read_text())
#         if group not in payload:
#             continue

#         freq_map = {}
#         for freq, metric_entries in payload[group].items():
#             if selected_freqs and freq not in selected_freqs:
#                 continue
#             by_metric = {entry["metric"]: entry for entry in metric_entries}

#             cpu_avg = _merge_cpu_sockets_avg(by_metric.get(METRIC_MAP["cpu"], {}).get("series", []), tolerance=tolerance)
#             dram_avg = _single_series_avg(by_metric.get(METRIC_MAP["dram"], {}).get("series", []))
#             system_avg = _single_series_avg(by_metric.get(METRIC_MAP["system"], {}).get("series", []))

#             if cpu_avg is None and dram_avg is None and system_avg is None:
#                 continue

#             freq_map[freq] = {"cpu": cpu_avg, "dram": dram_avg, "system": system_avg}

#         if freq_map:
#             avg_power[app_dir.name] = freq_map

#     return avg_power


# metrics_apps_dir = find_metrics_apps_dir(Path.cwd())

# avg_power_results = load_avg_powers_from_metrics(
#     metrics_apps_dir,
#     group=group,
#     selected_freqs=selected_freqs,
#     tolerance="1min",
# )

# len(avg_power_results), next(iter(avg_power_results.items())) if avg_power_results else None

# %%
# # Plot relative performance and average power vs frequency in three figures
# import math
# import matplotlib.pyplot as plt

# def build_lookup(pairs):
#     return {freq: value for freq, value in pairs}


# def plot_perf_and_power(metric_key, metric_label):
#     apps = sorted(set(perf_results.keys()) & set(avg_power_results.keys()))
#     if 'selected' in globals() and selected:
#         apps = [app for app in selected if app in perf_results and app in avg_power_results]

#     if not apps:
#         print(f'No apps available for plotting {metric_key}.')
#         return

#     # Build one shared right-axis range for this metric across all subplots.
#     all_power_vals = []
#     for app in apps:
#         perf_map = build_lookup(perf_results[app])
#         power_map = avg_power_results[app]
#         freqs = sorted(set(perf_map.keys()) & set(power_map.keys()), key=freq_value)
#         for f in freqs:
#             v = power_map[f].get(metric_key)
#             if v is not None:
#                 all_power_vals.append(float(v))

#     if all_power_vals:
#         pmin = min(all_power_vals)
#         pmax = max(all_power_vals)
#         if pmin == pmax:
#             pad = max(1.0, abs(pmin) * 0.05)
#         else:
#             pad = (pmax - pmin) * 0.05
#         right_ylim = (pmin - pad, pmax + pad)
#     else:
#         right_ylim = None

#     cols = 4
#     rows = math.ceil(len(apps) / cols)
#     fig, axes = plt.subplots(rows, cols, figsize=(cols * 6, rows * 4))
#     axes = axes.flatten() if hasattr(axes, 'flatten') else [axes]

#     for ax, app in zip(axes, apps):
#         perf_map = build_lookup(perf_results[app])
#         power_map = avg_power_results[app]

#         freqs = sorted(set(perf_map.keys()) & set(power_map.keys()), key=freq_value)
#         if not freqs:
#             ax.axis('off')
#             continue

#         x = [float(f.replace('GHz', '')) for f in freqs]
#         perf_vals = [perf_map[f] for f in freqs]
#         pwr_vals = [power_map[f].get(metric_key) for f in freqs]

#         ax.plot(x, perf_vals, marker='o', color='tab:blue')
#         ax.set_title(app)
#         ax.set_xlabel('Frequency (GHz)')
#         ax.set_ylabel(f'Relative performance to {baseline_freq}', color='tab:blue')
#         ax.set_xticks(x, freqs, rotation=45)
#         ax.set_ylim(0, 1.1)
#         ax.tick_params(axis='y', labelcolor='tab:blue')

#         ax2 = ax.twinx()
#         ax2.plot(x, pwr_vals, marker='s', color='tab:red')
#         ax2.set_ylabel(f'Avg {metric_label} power (W)', color='tab:red')
#         ax2.tick_params(axis='y', labelcolor='tab:red')
#         if right_ylim is not None:
#             ax2.set_ylim(*right_ylim)

#     for ax in axes[len(apps):]:
#         ax.axis('off')

#     fig.suptitle(f'Relative performance and average {metric_label} power vs frequency', y=1.02)
#     fig.tight_layout()
#     plt.show()


# plot_perf_and_power('cpu', 'CPU')
# plot_perf_and_power('dram', 'DRAM')
# plot_perf_and_power('system', 'System')

# %%
# # Find best frequency for lowest energy and lowest EDP using avg CPU/DRAM/System power
# import pandas as pd

# POWER_METRICS = {
#     'cpu': 'CPU',
#     'dram': 'DRAM',
#     'system': 'System',
# }


# def _pairs_to_lookup(pairs):
#     return {freq: value for freq, value in pairs}


# apps = sorted(set(raw_results.keys()) & set(avg_power_results.keys()))
# if 'selected' in globals() and selected:
#     apps = [app for app in selected if app in raw_results and app in avg_power_results]

# best_by_power = {}

# for metric_key, metric_label in POWER_METRICS.items():
#     rows = []
#     for app in apps:
#         runtime_map = _pairs_to_lookup(raw_results[app])
#         avg_map = avg_power_results[app]

#         freqs = sorted(set(runtime_map.keys()) & set(avg_map.keys()), key=freq_value)
#         energy_vals = {}
#         edp_vals = {}

#         for f in freqs:
#             avg_power = avg_map[f].get(metric_key)
#             runtime_s = runtime_map[f]
#             if avg_power is None or runtime_s is None:
#                 continue
#             energy_j = float(avg_power) * float(runtime_s)
#             edp_j_s = energy_j * float(runtime_s)
#             energy_vals[f] = energy_j
#             edp_vals[f] = edp_j_s

#         if not energy_vals:
#             continue

#         best_energy_freq = min(energy_vals, key=energy_vals.get)
#         best_edp_freq = min(edp_vals, key=edp_vals.get)

#         rows.append({
#             'app': app,
#             'best_energy_freq': best_energy_freq,
#             'energy_j': energy_vals[best_energy_freq],
#             'runtime_s_at_best_energy': runtime_map[best_energy_freq],
#             'best_edp_freq': best_edp_freq,
#             'edp_j_s': edp_vals[best_edp_freq],
#             'runtime_s_at_best_edp': runtime_map[best_edp_freq],
#         })

#     best_by_power[metric_key] = pd.DataFrame(rows).sort_values('app') if rows else pd.DataFrame()

# best_by_power

# %%
# # Display best-frequency tables
# for metric_key, metric_label in POWER_METRICS.items():
#     print(f'\n=== {metric_label} power-derived best frequencies ===')
#     df = best_by_power.get(metric_key)
#     if df is None or df.empty:
#         print('No data')
#         continue
#     display(df)
